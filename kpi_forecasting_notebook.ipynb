# %% [markdown]
# # Power BI KPI Dashboard & Forecasting Models\nPortfolio project based on IT, data analytics, KPI reporting, and forecasting experience.

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\n\ndf = pd.read_csv('sample_kpi_dataset.csv')\ndf.head()

# %%
df.describe()

# %%
df['Month'] = pd.to_datetime(df['Month'])\nplt.figure(figsize=(10,5))\nplt.plot(df['Month'], df['KPI_Performance_Score'], marker='o')\nplt.title('KPI Performance Score Trend')\nplt.xlabel('Month')\nplt.ylabel('Score')\nplt.xticks(rotation=45)\nplt.tight_layout()\nplt.show()

# %% [markdown]
# ## Business Insight\nThis project demonstrates how KPI dashboards and forecasting outputs can support better management visibility and reporting accuracy.
